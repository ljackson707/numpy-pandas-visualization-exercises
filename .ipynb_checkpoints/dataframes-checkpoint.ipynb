# %%
from pydataset import data
import pandas as pd
import numpy as np

# %%
mpg = data('mpg')
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize
# 234  midsize
#
# [234 rows x 11 columns]

# %%
#1) Copy the code from the lesson to create a dataframe full of student grades.
np.random.seed(123)

students = ['Sally', 'Jane', 'Suzie', 'Billy', 'Ada', 'John', 'Thomas',
            'Marie', 'Albert', 'Richard', 'Isaac', 'Alan']

# randomly generate scores for each student for each subject
# note that all the values need to have the same length here
math_grades = np.random.randint(low=60, high=100, size=len(students))
english_grades = np.random.randint(low=60, high=100, size=len(students))
reading_grades = np.random.randint(low=60, high=100, size=len(students))

df = pd.DataFrame({'name': students,
                   'math': math_grades,
                   'english': english_grades,
                   'reading': reading_grades})
df
# Out:
#        name  math  english  reading
# 0     Sally    62       85       80
# 1      Jane    88       79       67
# 2     Suzie    94       74       95
# 3     Billy    98       96       88
# 4       Ada    77       92       98
# 5      John    79       76       93
# 6    Thomas    82       64       81
# 7     Marie    93       63       90
# 8    Albert    92       62       87
# 9   Richard    69       80       94
# 10    Isaac    92       99       93
# 11     Alan    92       62       72

# %%
df.shape
# Out:
# (12, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     12 non-null     object
#  1   math     12 non-null     int64
#  2   english  12 non-null     int64
#  3   reading  12 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 512.0+ bytes

# %%
#A) Create a column named passing_english that indicates whether each student has a passing grade in english.
new_df = df.assign(passing_english = df.english >= 70)
new_df
# Out:
#        name  math  english  reading  passing_english
# 0     Sally    62       85       80             True
# 1      Jane    88       79       67             True
# 2     Suzie    94       74       95             True
# 3     Billy    98       96       88             True
# 4       Ada    77       92       98             True
# 5      John    79       76       93             True
# 6    Thomas    82       64       81            False
# 7     Marie    93       63       90            False
# 8    Albert    92       62       87            False
# 9   Richard    69       80       94             True
# 10    Isaac    92       99       93             True
# 11     Alan    92       62       72            False

# %%
#B)Sort the english grades by the passing_english column. How are duplicates handled?
new_df.sort_values(by = 'passing_english') # drops the duplicates, we need to use a keep all function to keep this from happening
# Out:
#        name  math  english  reading  passing_english
# 6    Thomas    82       64       81            False
# 7     Marie    93       63       90            False
# 8    Albert    92       62       87            False
# 11     Alan    92       62       72            False
# 0     Sally    62       85       80             True
# 1      Jane    88       79       67             True
# 2     Suzie    94       74       95             True
# 3     Billy    98       96       88             True
# 4       Ada    77       92       98             True
# 5      John    79       76       93             True
# 9   Richard    69       80       94             True
# 10    Isaac    92       99       93             True

# %%
new_df['passing_english'].sum()
# Out:
# 8

# %%
#C) Sort the english grades first by passing_english and then by student name. 
#All the students that are failing english should be first, 
#and within the students that are failing english they should be ordered alphabetically. 
#The same should be true for the students passing english. 
#(Hint: you can pass a list to the .sort_values method)

new_df.sort_values(by=['passing_english', 'name'], ascending = [True, True])
# Out:
#        name  math  english  reading  passing_english
# 11     Alan    92       62       72            False
# 8    Albert    92       62       87            False
# 7     Marie    93       63       90            False
# 6    Thomas    82       64       81            False
# 4       Ada    77       92       98             True
# 3     Billy    98       96       88             True
# 10    Isaac    92       99       93             True
# 1      Jane    88       79       67             True
# 5      John    79       76       93             True
# 9   Richard    69       80       94             True
# 0     Sally    62       85       80             True
# 2     Suzie    94       74       95             True

# %%
(new_df['passing_english'] == False).sum()
# Out:
# 4

# %%
#D) Sort the english grades first by passing_english, and then by the actual english grade, 
#similar to how we did in the last step.
new_df.sort_values(by=['passing_english', 'english'], ascending = [False, False])
# Out:
#        name  math  english  reading  passing_english
# 10    Isaac    92       99       93             True
# 3     Billy    98       96       88             True
# 4       Ada    77       92       98             True
# 0     Sally    62       85       80             True
# 9   Richard    69       80       94             True
# 1      Jane    88       79       67             True
# 5      John    79       76       93             True
# 2     Suzie    94       74       95             True
# 6    Thomas    82       64       81            False
# 7     Marie    93       63       90            False
# 8    Albert    92       62       87            False
# 11     Alan    92       62       72            False

# %%
#E) Calculate each students overall grade and add it as a column on the dataframe. 
#The overall grade is the average of the math, english, and reading grades.
new_df = df.assign(overall_grade = (df.math+df.english+df.reading)/3)
new_df.round(0)
# Out:
#        name  math  english  reading  overall_grade
# 0     Sally    62       85       80           76.0
# 1      Jane    88       79       67           78.0
# 2     Suzie    94       74       95           88.0
# 3     Billy    98       96       88           94.0
# 4       Ada    77       92       98           89.0
# 5      John    79       76       93           83.0
# 6    Thomas    82       64       81           76.0
# 7     Marie    93       63       90           82.0
# 8    Albert    92       62       87           80.0
# 9   Richard    69       80       94           81.0
# 10    Isaac    92       99       93           95.0
# 11     Alan    92       62       72           75.0

# %%
# This method also works
new_df['overall_average'] = round(new_df.loc[:, 'math': 'reading'].sum(axis=1)/3).astype(int)
new_df
# Out:
#        name  math  english  reading  overall_grade  overall_average
# 0     Sally    62       85       80      75.666667               76
# 1      Jane    88       79       67      78.000000               78
# 2     Suzie    94       74       95      87.666667               88
# 3     Billy    98       96       88      94.000000               94
# 4       Ada    77       92       98      89.000000               89
# 5      John    79       76       93      82.666667               83
# 6    Thomas    82       64       81      75.666667               76
# 7     Marie    93       63       90      82.000000               82
# 8    Albert    92       62       87      80.333333               80
# 9   Richard    69       80       94      81.000000               81
# 10    Isaac    92       99       93      94.666667               95
# 11     Alan    92       62       72      75.333333               75

# %%
#2) Load the mpg dataset. 
#Read the documentation for the dataset and use it for the following questions:
mpg = data('mpg')
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize
# 234  midsize
#
# [234 rows x 11 columns]

# %%
#a) How many rows and columns are there?
mpg.shape
# Out:
# (234, 11)

# %%
#b) What are the data types of each column?
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   city          234 non-null    int64
#  8   highway       234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 31.9+ KB

# %%
#c) Summarize the dataframe with .info and .describe
mpg.describe()
# Out:
#             displ         year         cyl        city     highway
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %%
#d) Rename the cty column to city.
new_mpg = mpg.rename(columns={'cty': 'city'})
new_mpg.columns
# Out:
# Index(['manufacturer', 'model', 'displ', 'year', 'cyl', 'trans', 'drv', 'city',
#        'highway', 'fl', 'class'],
#       dtype='object')

# %%
#e) Rename the hwy column to highway.
new_mpg = mpg.rename(columns={'hwy': 'highway'})
new_mpg.columns
# Out:
# Index(['manufacturer', 'model', 'displ', 'year', 'cyl', 'trans', 'drv', 'city',
#        'highway', 'fl', 'class'],
#       dtype='object')

# %%
#f) Do any cars have better city mileage than highway mileage?
new_mpg = mpg.sort_values(by=['city', 'highway'], ascending = [False, False])
new_mpg
# Out:
#     manufacturer                model  displ  year  cyl       trans drv  city  \
# 222   volkswagen           new beetle    1.9  1999    4  manual(m5)   f    35
# 213   volkswagen                jetta    1.9  1999    4  manual(m5)   f    33
# 223   volkswagen           new beetle    1.9  1999    4    auto(l4)   f    29
# 197       toyota              corolla    1.8  2008    4  manual(m5)   f    28
# 100        honda                civic    1.6  1999    4  manual(m5)   f    28
# ..           ...                  ...    ...   ...  ...         ...  ..   ...
# 55         dodge    dakota pickup 4wd    4.7  2008    8    auto(l5)   4     9
# 60         dodge          durango 4wd    4.7  2008    8    auto(l5)   4     9
# 66         dodge  ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4     9
# 70         dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4     9
# 127         jeep   grand cherokee 4wd    4.7  2008    8    auto(l5)   4     9
#
#      highway fl       class
# 222       44  d  subcompact
# 213       44  d     compact
# 223       41  d  subcompact
# 197       37  r     compact
# 100       33  r  subcompact
# ..       ... ..         ...
# 55        12  e      pickup
# 60        12  e         suv
# 66        12  e      pickup
# 70        12  e      pickup
# 127       12  e         suv
#
# [234 rows x 11 columns]

# %%
#g) Create a column named mileage_difference 
#this column should contain the difference between highway and city mileage for each car.
new_mpg = (mpg.assign(mileage_difference = (mpg.highway - mpg.city))
.sort_values(by = 'mileage_difference', ascending = False))
new_mpg
# Out:
#     manufacturer              model  displ  year  cyl       trans drv  city  \
# 107        honda              civic    1.8  2008    4    auto(l5)   f    24
# 223   volkswagen         new beetle    1.9  1999    4    auto(l4)   f    29
# 1           audi                 a4    1.8  1999    4    auto(l5)   f    18
# 229   volkswagen             passat    1.8  1999    4    auto(l5)   f    18
# 36     chevrolet             malibu    3.5  2008    6    auto(l4)   f    18
# ..           ...                ...    ...   ...  ...         ...  ..   ...
# 80          ford       explorer 4wd    4.0  1999    6    auto(l5)   4    14
# 138      mercury    mountaineer 4wd    4.0  1999    6    auto(l5)   4    14
# 177       toyota        4runner 4wd    3.4  1999    6  manual(m5)   4    15
# 152       nissan     pathfinder 4wd    3.3  1999    6  manual(m5)   4    15
# 204       toyota  toyota tacoma 4wd    3.4  1999    6  manual(m5)   4    15
#
#      highway fl       class  mileage_difference
# 107       36  c  subcompact                  12
# 223       41  d  subcompact                  12
# 1         29  p     compact                  11
# 229       29  p     midsize                  11
# 36        29  r     midsize                  11
# ..       ... ..         ...                 ...
# 80        17  r         suv                   3
# 138       17  r         suv                   3
# 177       17  r         suv                   2
# 152       17  r         suv                   2
# 204       17  r      pickup                   2
#
# [234 rows x 12 columns]

# %%
#h) Which car (or cars) has the highest mileage difference?
new_mpg.nlargest(1, 'mileage_difference', keep='all')
# Out:
#     manufacturer       model  displ  year  cyl     trans drv  city  highway  \
# 107        honda       civic    1.8  2008    4  auto(l5)   f    24       36
# 223   volkswagen  new beetle    1.9  1999    4  auto(l4)   f    29       41
#
#     fl       class  mileage_difference
# 107  c  subcompact                  12
# 223  d  subcompact                  12

# %%
#i) Which compact class car has the lowest highway mileage? The best?
new_mpg_low = (new_mpg[new_mpg['class'] == 'compact']
.sort_values(by = 'highway', ascending = False)
.tail(1))
new_mpg_low
# Out:
#     manufacturer  model  displ  year  cyl     trans drv  city  highway fl  \
# 220   volkswagen  jetta    2.8  1999    6  auto(l4)   f    16       23  r
#
#        class  mileage_difference
# 220  compact                   7

# %%
# The best
new_mpg_high = (new_mpg[new_mpg['class'] == 'compact']
.sort_values(by = 'highway', ascending = False)
.head(1))
new_mpg_high
# Out:
#     manufacturer  model  displ  year  cyl       trans drv  city  highway fl  \
# 213   volkswagen  jetta    1.9  1999    4  manual(m5)   f    33       44  d
#
#        class  mileage_difference
# 213  compact                  11

# %%
#j) Create a column named average_mileage that is the mean of the city and highway mileage.
new_mpg = (mpg.assign(average_mileage = (mpg.highway + mpg.city)/2)
.sort_values(by = 'average_mileage', ascending = False))
new_mpg
# Out:
#     manufacturer                model  displ  year  cyl       trans drv  city  \
# 222   volkswagen           new beetle    1.9  1999    4  manual(m5)   f    35
# 213   volkswagen                jetta    1.9  1999    4  manual(m5)   f    33
# 223   volkswagen           new beetle    1.9  1999    4    auto(l4)   f    29
# 197       toyota              corolla    1.8  2008    4  manual(m5)   f    28
# 196       toyota              corolla    1.8  1999    4  manual(m5)   f    26
# ..           ...                  ...    ...   ...  ...         ...  ..   ...
# 127         jeep   grand cherokee 4wd    4.7  2008    8    auto(l5)   4     9
# 60         dodge          durango 4wd    4.7  2008    8    auto(l5)   4     9
# 66         dodge  ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4     9
# 70         dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4     9
# 55         dodge    dakota pickup 4wd    4.7  2008    8    auto(l5)   4     9
#
#      highway fl       class  average_mileage
# 222       44  d  subcompact             39.5
# 213       44  d     compact             38.5
# 223       41  d  subcompact             35.0
# 197       37  r     compact             32.5
# 196       35  r     compact             30.5
# ..       ... ..         ...              ...
# 127       12  e         suv             10.5
# 60        12  e         suv             10.5
# 66        12  e      pickup             10.5
# 70        12  e      pickup             10.5
# 55        12  e      pickup             10.5
#
# [234 rows x 12 columns]

# %%
#k) Which dodge car has the best average mileage? The worst?

# The best
new_mpg_h = (new_mpg[new_mpg['manufacturer'] == 'dodge']
.sort_values(by = 'average_mileage', ascending = False)
.head(1))
new_mpg_h
# Out:
#    manufacturer        model  displ  year  cyl     trans drv  city  highway  \
# 38        dodge  caravan 2wd    2.4  1999    4  auto(l3)   f    18       24
#
#    fl    class  average_mileage
# 38  r  minivan             21.0

# %%
# The Worst
new_mpg_l = (new_mpg[new_mpg['manufacturer'] == 'dodge']
.sort_values(by = 'average_mileage', ascending = False)
.tail(4))
new_mpg_l
# Out:
#    manufacturer                model  displ  year  cyl       trans drv  city  \
# 60        dodge          durango 4wd    4.7  2008    8    auto(l5)   4     9
# 66        dodge  ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4     9
# 70        dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4     9
# 55        dodge    dakota pickup 4wd    4.7  2008    8    auto(l5)   4     9
#
#     highway fl   class  average_mileage
# 60       12  e     suv             10.5
# 66       12  e  pickup             10.5
# 70       12  e  pickup             10.5
# 55       12  e  pickup             10.5

# %%
#3) Load the Mammals dataset. Read the documentation for it, 
#and use the data to answer these questions:

mammals = data('Mammals')
mammals
# Out:
#        weight  speed  hoppers  specials
# 1    6000.000   35.0    False     False
# 2    4000.000   26.0    False     False
# 3    3000.000   25.0    False     False
# 4    1400.000   45.0    False     False
# 5     400.000   70.0    False     False
# 6     350.000   70.0    False     False
# 7     300.000   64.0    False     False
# 8     260.000   70.0    False     False
# 9     250.000   40.0    False     False
# 10   3800.000   25.0    False      True
# 11   1000.000   60.0    False     False
# 12    900.000   70.0    False     False
# 13    900.000   56.0    False     False
# 14    800.000   29.0    False     False
# 15    750.000   57.0    False     False
# 16    500.000   32.0    False     False
# 17    450.000   56.0    False     False
# 18    300.000   72.0    False     False
# 19    300.000   90.0    False     False
# 20    250.000   80.0    False     False
# 21    250.000   56.0    False     False
# 22    170.000   80.0    False     False
# 23    150.000   48.0    False     False
# 24    130.000   70.0    False     False
# 25    120.000   80.0    False     False
# 26    120.000   61.0    False     False
# 27    110.000   33.0    False     False
# 28    100.000   64.0    False     False
# 29     85.000   55.0    False     False
# 30     80.000   65.0    False     False
# 31     72.000   56.0    False     False
# 32     70.000   45.0    False     False
# 33     65.000   60.0    False     False
# 34     62.000   81.0    False     False
# 35     50.000  100.0    False     False
# 36     50.000   60.0    False     False
# 37     50.000   40.0    False     False
# 38     50.000   47.0    False     False
# 39     37.000  105.0    False     False
# 40     35.000   80.0    False     False
# 41     34.000   97.0    False     False
# 42     30.000   97.0    False     False
# 43     30.000   80.0    False     False
# 44     30.000   45.0    False     False
# 45     20.000   81.0    False     False
# 46    400.000   40.0    False     False
# 47    300.000   48.0    False     False
# 48    230.000   56.0    False     False
# 49    150.000   59.0    False     False
# 50    135.000   48.0    False     False
# 51     65.000   65.0    False     False
# 52     60.000   60.0    False     False
# 53     55.000  110.0    False     False
# 54     45.000   50.0    False     False
# 55     40.000   64.0    False     False
# 56     25.000   67.0    False     False
# 57     20.000   70.0    False     False
# 58     16.000   65.0    False     False
# 59     12.000   24.0    False      True
# 60     11.000   30.0    False      True
# 61     10.000   56.0    False     False
# 62      7.000   60.0    False     False
# 63      6.000   72.0    False     False
# 64      5.000   64.0    False     False
# 65      5.000   27.0    False      True
# 66      3.000   16.0    False      True
# 67    127.000   32.0    False     False
# 68     70.000   40.0    False      True
# 69     13.000   37.0    False      True
# 70      9.000    3.2    False      True
# 71      4.000   16.0    False     False
# 72      0.600   36.0    False     False
# 73      0.600   20.0    False     False
# 74      0.550   27.0    False     False
# 75      0.500   18.0    False     False
# 76      0.400   20.0    False     False
# 77      0.300   13.0    False     False
# 78      0.250    9.7    False     False
# 79      0.220   15.0    False     False
# 80      0.110    9.0    False     False
# 81      0.100   17.0    False     False
# 82      0.056   21.0     True     False
# 83      0.050   11.0    False     False
# 84      0.045   16.0    False     False
# 85      0.035   32.0     True     False
# 86      0.035   14.0     True     False
# 87      0.030    6.8    False     False
# 88      0.030    9.1    False     False
# 89      0.025   11.0    False     False
# 90      0.025    8.6    False     False
# 91      0.018    8.9    False     False
# 92      0.016   13.0    False     False
# 93      0.100    4.0    False     False
# 94      0.100    2.4    False     False
# 95      0.016    3.6    False     False
# 96      4.600   64.0     True     False
# 97      4.400   72.0     True     False
# 98      4.000   72.0     True     False
# 99      3.500   56.0     True     False
# 100     2.000   64.0     True     False
# 101     1.900   56.0     True     False
# 102     1.500   50.0     True     False
# 103     1.500   40.0     True     False
# 104    50.000   65.0    False     False
# 105     5.000    7.4    False      True
# 106     0.024   13.0    False     False
# 107     4.000    1.6    False      True

# %%
#a) How many rows and columns are there?
mammals.shape
# Out:
# (107, 4)

# %%
#b) What are the data types?
mammals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 107 entries, 1 to 107
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   weight    107 non-null    float64
#  1   speed     107 non-null    float64
#  2   hoppers   107 non-null    bool
#  3   specials  107 non-null    bool
# dtypes: bool(2), float64(2)
# memory usage: 2.7 KB

# %%
mammals.dtypes
# Out:
# weight      float64
# speed       float64
# hoppers        bool
# specials       bool
# dtype: object

# %%
#c) Summarize the dataframe with .info and .describe
mammals.info(), mammals.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 107 entries, 1 to 107
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   weight    107 non-null    float64
#  1   speed     107 non-null    float64
#  2   hoppers   107 non-null    bool
#  3   specials  107 non-null    bool
# dtypes: bool(2), float64(2)
# memory usage: 2.7 KB
# (None,
#              weight       speed
#  count   107.000000  107.000000
#  mean    278.688178   46.208411
#  std     839.608269   26.716778
#  min       0.016000    1.600000
#  25%       1.700000   22.500000
#  50%      34.000000   48.000000
#  75%     142.500000   65.000000
#  max    6000.000000  110.000000)

# %%
#d) What is the the weight of the fastest animal?
weight_of_fast = mammals.sort_values(by = 'speed', ascending = False).head(1)
weight_of_fast
# Out:
#     weight  speed  hoppers  specials
# 53    55.0  110.0    False     False

# %%
#e) What is the overal percentage of specials?
mammals.specials.value_counts(normalize=True).mul(100).astype(str)+'%'
# Out:
# False    90.65420560747664%
# True     9.345794392523365%
# Name: specials, dtype: object

# %%
#f) How many animals are hoppers that are above the median speed? What percentage is this?
med_speed= (sum(mammals.speed)/107)
med_speed

hoppers_over_mspeed = (mammals.assign(percent_hop_over_med_speed = (mammals.hoppers == 1) & (mammals.speed > med_speed))
.sort_values(by = ['hoppers','percent_hop_over_med_speed'], ascending = [False, False] ))
hoppers_over_mspeed


hoppers_over_mspeed.percent_hop_over_med_speed.value_counts(normalize=True).mul(100).astype(str)+'%'
# Out:
# False     93.45794392523365%
# True     6.5420560747663545%
# Name: percent_hop_over_med_speed, dtype: object

# %%
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
#E) What is the overal percentage of specials? (Easier Way)
total_specials = mammals.specials.sum()
total_specials
# Out:
# 10

# %%
total_mammals = len(mammals)
total_mammals
# Out:
# 107

# %%
round(total_specials/total_mammals * 100, 2)
# Out:
# 9.35

# %%
#F) How many animals are hoppers that are above the median speed? What percentage is this? (Easier Way))
